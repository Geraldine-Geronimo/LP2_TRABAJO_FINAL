# %% [markdown]
# REPOSITORIO UNA

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup

html_unsa = urllib.request.urlopen("http://repositorio.unsa.edu.pe/browse?type=dateissued").read()
url_unsa = BeautifulSoup(html_unsa, 'html.parser')

# %%
html_unalm = urllib.request.urlopen("https://repositorio.lamolina.edu.pe/browse?type=dateissued").read()
url_unalm = BeautifulSoup(html, 'html.parser')
url_unalm

# %%
import urllib.request
x = urllib.request.urlopen ('http://repositorio.unsa.edu.pe/handle/UNSA/6229?show=full')

from bs4 import BeautifulSoup
sopa = BeautifulSoup(x)
#sopa = sopa.prettify()
#print(sopa)
# Out:
# C:\Users\Geraldine\anaconda3\lib\site-packages\bs4\builder\__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
import requests
import pandas as pd
headers = {"User-agent": 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'}
respuesta = requests.get("http://tesis.unap.edu.pe/handle/20.500.14082/632?show=full", headers=headers)
tabla_tesis = pd.read_html(respuesta.content, encoding = 'utf8')

# %%
tabla_1 = tabla_tesis[0]
#tabla_1.to_csv('example1.csv', index=False)
#pd.read_csv('example1.csv')
#pd.read_csv('example1.csv', header=None, skiprows=2)

# %%
tabla_1
# Out:
#                            0  \
# 0     dc.contributor.advisor
# 1      dc.contributor.author
# 2        dc.date.accessioned
# 3          dc.date.available
# 4             dc.date.issued
# 5        dc.identifier.other
# 6          dc.identifier.uri
# 7    dc.description.abstract
# 8         dc.description.uri
# 9            dc.language.iso
# 10              dc.publisher
# 11                 dc.rights
# 12             dc.rights.uri
# 13                 dc.source
# 14                 dc.source
# 15                dc.subject
# 16                  dc.title
# 17                   dc.type
# 18        thesis.degree.name
# 19  thesis.degree.discipline
# 20     thesis.degree.grantor
# 21       thesis.degree.level
#
#                                                     1      2
# 0                          Calsín Velásquez, Wilfredo    NaN
# 1                     Aparicio Aragón, Walter Benigno    NaN
# 2                                2016-09-17T00:43:27Z    NaN
# ...

# %%
años = []
instituciones = []
titulos = []
autores = []
contribuidores = []
grados = []
resumenes = []
n = 0


for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'dc.date.issued':
        año=tabla_1.iloc[i,1]
        años.append(año)
        n = n + 1
if n == 0:
    años.append(" ")

else:
    n = 0

    
    
for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'dc.publisher':
        institucion=tabla_1.iloc[i,1]
        instituciones.append(institucion)
        n = n + 1
if n == 0:
    instituciones.append(" ")
    
else:
    n = 0

    
    
for i in range(len(tabla_1)):        
    if tabla_1.iloc[i,0] == 'dc.title':
        titulo=tabla_1.iloc[i,1]
        titulos.append(titulo)
        n = n + 1
if n == 0:
        titulos.append(" ")

else:
    n = 0

    
    
for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'dc.contributor.author':
        autor=tabla_1.iloc[i,1]
        autores.append(autor)
        n = n + 1
        break
if n == 0:
        autores.append(" ")

else:
    n = 0 

    
    
for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'thesis.degree.name':
        grado=tabla_1.iloc[i,1]
        grados.append(grado)
        n = n + 1
if n == 0:
        grados.append(" ")

else:
    n = 0

    
    
for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'dc.contributor.advisor':
        contribuidor=tabla_1.iloc[i,1]
        contribuidores.append(contribuidor)
        n = n + 1
if n == 0:
        contribuidores.append(" ")
else:
    n = 0



for i in range(len(tabla_1)):
    if tabla_1.iloc[i,0] == 'dc.description.abstract':
        resumen=tabla_1.iloc[i,1]
        resumenes.append(resumen)
        n = n + 1
if n == 0:
        resumenes.append(" ")
else:
    n = 0
        
    
    
print('Lista de años: ',años)
print('Lista de instituciones: ',instituciones)
print('Lista de titulos: ',titulos)
print('Lista de autores: ',autores)
print('Lista de contribuidores: ',contribuidores)
print('Lista de grados: ',grados)
print('Lista de resumenes: ',resumenes)
# Out:
# Lista de años:  ['2002']
# Lista de instituciones:  ['Universidad Nacional del Altiplano']
# Lista de titulos:  ['Determinación de la capacidad de adsorción del chacko aplicado a la extracción de cationes metálicos']
# Lista de autores:  ['Aparicio Aragón, Walter Benigno']
# Lista de contribuidores:  ['Calsín Velásquez, Wilfredo']
# Lista de grados:  ['Magíster Scientiae en Extracción de Metales Estratégicos.']
# ...
